# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayali-kadam10/6239sayalidvproject/blob/main/data_science_practical_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data= pd.read_csv("/data_sci2.csv")

print(data)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
import pandas as pd
data= pd.read_excel("/data_sci2.xlsx")

print(data)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img=mpimg.imread("/image1.jpg")
plt.imshow(img)

# %%
import pandas as pd
df=pd.DataFrame (
    {
        "Roll No.":[6221,6222,6223,6224,6225,6226,6227,6228,6229,6230],
        "Name":['sayali','siddhu','jagu','sahil','sanika','kiran','sakshi','karishma','shraddha','rushi'],
        "Marks":[90,89,80,80,87,68,67,70,80,85]
    }
)

# %%
print (df)
# Out:
#    Roll No.      Name  Marks
# 0      6221    sayali     90
# 1      6222    siddhu     89
# 2      6223      jagu     80
# 3      6224     sahil     80
# 4      6225    sanika     87
# 5      6226     kiran     68
# 6      6227    sakshi     67
# 7      6228    sakshi     70
# 8      6229  shraddha     80
# 9      6230     rushi     85

# %%
df.isnull()
# Out:
#    Roll No.   Name  Marks
# 0     False  False  False
# 1     False  False  False
# 2     False  False  False
# 3     False  False  False
# 4     False  False  False
# 5     False  False  False
# 6     False  False  False
# 7     False  False  False
# 8     False  False  False
# 9     False  False  False

# %%
df.describe()
# Out:
#          Roll No.      Marks
# count    10.00000  10.000000
# mean   6225.50000  79.600000
# std       3.02765   8.604908
# min    6221.00000  67.000000
# 25%    6223.25000  72.500000
# 50%    6225.50000  80.000000
# 75%    6227.75000  86.500000
# max    6230.00000  90.000000

# %%
df.describe(include='object')
# Out:
#           Name
# count       10
# unique      10
# top     sayali
# freq         1

# %%
df.shape
# Out:
# (10, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Roll No.  10 non-null     int64
#  1   Name      10 non-null     object
#  2   Marks     10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 368.0+ bytes

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of    Roll No.      Name  Marks
# 0      6221    sayali     90
# 1      6222    siddhu     89
# 2      6223      jagu     80
# 3      6224     sahil     80
# 4      6225    sanika     87
# 5      6226     kiran     68
# 6      6227    sakshi     67
# 7      6228  karishma     70
# 8      6229  shraddha     80
# 9      6230     rushi     85>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.value_counts()
# Out:
# Roll No.  Name      Marks
# 6221      sayali    90       1
# 6222      siddhu    89       1
# 6223      jagu      80       1
# 6224      sahil     80       1
# 6225      sanika    87       1
# 6226      kiran     68       1
# 6227      sakshi    67       1
# 6228      karishma  70       1
# 6229      shraddha  80       1
# 6230      rushi     85       1
# dtype: int64

# %%
df['Name'].value_counts()
# Out:
# sayali      1
# siddhu      1
# jagu        1
# sahil       1
# sanika      1
# kiran       1
# sakshi      1
# karishma    1
# shraddha    1
# rushi       1
# Name: Name, dtype: int64

# %%
correlation=df.corr()
# Out:
# <ipython-input-44-0c9b4bd1cb53>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(correlation, annot=True,fmt='.3f',cmap='viridis')
# Out:
# <Axes: >

# %%
df.var()
# Out:
# <ipython-input-63-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Roll No.     9.166667
# Marks       74.044444
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-59-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Roll No.    6225.5
# Marks         79.6
# dtype: float64

# %%
df['Roll No.'].var()
# Out:
# 9.166666666666666

# %%
df.cov()
# Out:
# <ipython-input-73-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#            Roll No.      Marks
# Roll No.   9.166667 -12.000000
# Marks    -12.000000  74.044444

# %%
df.corr()
# Out:
# <ipython-input-74-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Roll No.     Marks
# Roll No.  1.000000 -0.460606
# Marks    -0.460606  1.000000
